# %%
import sys
import os
import pandas as pd

# Obtenha o diretório atual de trabalho
diretorio_atual = os.getcwd()

# Adicione o diretório do arquivo funcoes_teste_hipotese.py ao sys.path
diretorio_funcoes = os.path.join(diretorio_atual, "Teste de Hipótese - Brasileirão", "Testes de Hipótese")

# Adicione o diretório ao sys.path
sys.path.append(diretorio_funcoes)

# Importe a função do arquivo funcoes_teste_hipotese.py
import funcoes_teste_hipotese as fth

# %%
arquivo_treinadores = r"C:\Users\andre\Teste de Hipótese - Brasileirão\Tabelas geradas\Tabela Médias Treinadores - Ceará.csv"

# %%
df = pd.read_csv(arquivo_treinadores)
df
# Out:
#         Unnamed: 0  Número de jogos  Pontuação média  \
# 0  Eduardo Barroca               12         1.750000
# 1    Guto Ferreira               11         1.272727
# 2   Vagner Mancini               13         1.153846
#
#    Desvio padrão da média de pontos
# 0                          1.356801
# 1                          1.190874
# 2                          1.344504

# %%
fth.pontuacao_porjogo_treinador(arquivo_treinadores)

# %%
fth.t_obs_media_pontos_fccd_com_tabela(arquivo_treinadores)
# Out:
#                 Eduardo Barroca Guto Ferreira Vagner Mancini
# Eduardo Barroca               -             0              0
# Guto Ferreira                 0             -              0
# Vagner Mancini                0             0              -
