# %%
import sys
import os
import pandas as pd

# Obtenha o diretório atual de trabalho
diretorio_atual = os.getcwd()

# Adicione o diretório do arquivo funcoes_teste_hipotese.py ao sys.path
diretorio_funcoes = os.path.join(diretorio_atual, "Teste de Hipótese - Brasileirão", "Testes de Hipótese")

# Adicione o diretório ao sys.path
sys.path.append(diretorio_funcoes)

# Importe a função do arquivo funcoes_teste_hipotese.py
import funcoes_teste_hipotese as fth

# %%
arquivo_treinadores_corinthians = r"C:\Users\andre\Teste de Hipótese - Brasileirão\Tabelas geradas\Tabela Médias Treinadores - Corinthians.csv"

# %%
fth.pontuacao_porjogo_treinador(arquivo_treinadores_corinthians)

# %%
fth.barras_xG_treinador(arquivo_treinadores_corinthians)

# %%
fth.t_obs_media_pontos_fccd_com_tabela(arquivo_treinadores_corinthians)
# Out:
#                      Vanderlei Luxemburgo Mano Menezes
# Vanderlei Luxemburgo                    -            0
# Mano Menezes                            0            -

# %%
fth.t_obs_xGAFavor_fccd_com_tabela(arquivo_treinadores_corinthians)
# Out:
#                      Vanderlei Luxemburgo Mano Menezes
# Vanderlei Luxemburgo                    -            0
# Mano Menezes                            0            -

# %%
fth.t_obs_xGContra_fccd_com_tabela(arquivo_treinadores_corinthians)
# Out:
#                      Vanderlei Luxemburgo Mano Menezes
# Vanderlei Luxemburgo                    -            0
# Mano Menezes                            0            -
