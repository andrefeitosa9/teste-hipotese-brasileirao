# %%
import sys
import os
import pandas as pd

# Obtenha o diretório atual de trabalho
diretorio_atual = os.getcwd()

# Adicione o diretório do arquivo funcoes_teste_hipotese.py ao sys.path
diretorio_funcoes = os.path.join(diretorio_atual, "Teste de Hipótese - Brasileirão", "Testes de Hipótese")

# Adicione o diretório ao sys.path
sys.path.append(diretorio_funcoes)

# Importe a função do arquivo funcoes_teste_hipotese.py
import funcoes_teste_hipotese as fth

# %%
arquivo_treinadores_botafogo = r"C:\Users\andre\Teste de Hipótese - Brasileirão\Tabelas geradas\Tabela Médias Treinadores - Botafogo.csv"

# %%
fth.pontuacao_porjogo_treinador(arquivo_treinadores_botafogo)

# %%
fth.barras_xG_treinador(arquivo_treinadores_botafogo)

# %%
fth.t_obs_media_pontos_fccd_com_tabela(arquivo_treinadores_botafogo)
# Out:
#                Luis Castro Claudio Caçapa Bruno Lage Lucio Flávio Tiago Nunes
# Luis Castro              -              0          1            1           1
# Claudio Caçapa           0              -          0            1           1
# Bruno Lage               1              0          -            0           0
# Lucio Flávio             1              1          0            -           0
# Tiago Nunes              1              1          0            0           -

# %%
fth.t_obs_xGAFavor_fccd_com_tabela(arquivo_treinadores_botafogo)
# Out:
#                Luis Castro Claudio Caçapa Bruno Lage Lucio Flávio Tiago Nunes
# Luis Castro              -              0          0            0           0
# Claudio Caçapa           0              -          0            0           0
# Bruno Lage               0              0          -            0           0
# Lucio Flávio             0              0          0            -           0
# Tiago Nunes              0              0          0            0           -

# %%
fth.t_obs_xGContra_fccd_com_tabela(arquivo_treinadores_botafogo)
# Out:
#                Luis Castro Claudio Caçapa Bruno Lage Lucio Flávio Tiago Nunes
# Luis Castro              -              0          0            0           0
# Claudio Caçapa           0              -          0            0           0
# Bruno Lage               0              0          -            0           0
# Lucio Flávio             0              0          0            -           0
# Tiago Nunes              0              0          0            0           -
